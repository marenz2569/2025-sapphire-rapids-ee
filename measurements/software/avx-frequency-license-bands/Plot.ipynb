# %%
# %pip install seaborn
# Out:
# Requirement already satisfied: seaborn in /home/marenz/de/tu-dresden/zih/roco2/.venv/lib/python3.12/site-packages (0.13.2)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in /home/marenz/de/tu-dresden/zih/roco2/.venv/lib/python3.12/site-packages (from seaborn) (2.2.2)
# Requirement already satisfied: pandas>=1.2 in /home/marenz/de/tu-dresden/zih/roco2/.venv/lib/python3.12/site-packages (from seaborn) (2.2.3)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in /home/marenz/de/tu-dresden/zih/roco2/.venv/lib/python3.12/site-packages (from seaborn) (3.10.0)
# Requirement already satisfied: contourpy>=1.0.1 in /home/marenz/de/tu-dresden/zih/roco2/.venv/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /home/marenz/de/tu-dresden/zih/roco2/.venv/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/marenz/de/tu-dresden/zih/roco2/.venv/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.55.6)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/marenz/de/tu-dresden/zih/roco2/.venv/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /home/marenz/de/tu-dresden/zih/roco2/.venv/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (24.2)
# Requirement already satisfied: pillow>=8 in /home/marenz/de/tu-dresden/zih/roco2/.venv/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /home/marenz/de/tu-dresden/zih/roco2/.venv/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.2.1)
# Requirement already satisfied: python-dateutil>=2.7 in /home/marenz/de/tu-dresden/zih/roco2/.venv/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /home/marenz/de/tu-dresden/zih/roco2/.venv/lib/python3.12/site-packages (from pandas>=1.2->seaborn) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /home/marenz/de/tu-dresden/zih/roco2/.venv/lib/python3.12/site-packages (from pandas>=1.2->seaborn) (2025.1)
# Requirement already satisfied: six>=1.5 in /home/marenz/de/tu-dresden/zih/roco2/.venv/lib/python3.12/site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.17.0)
#
# [notice] A new release of pip is available: 24.3.1 -> 25.1.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib
import glob
import seaborn as sns

import sys
sys.path.append('parser')

from parser import IsstPerfProfile

# %%
files = glob.glob('results/*.datafile')
files
# Out:
# ['results/2025-02-17.datafile']

# %%
result = IsstPerfProfile.parse(files[0])
result.profiles
# Out:
# [Profile(package=1, die=0, cpu=56, level=0, turbo_levels=[TurboRatioLevel(level='0', core_count=1, max_turbo_frequency_mhz=3800), TurboRatioLevel(level='0', core_count=2, max_turbo_frequency_mhz=3800), TurboRatioLevel(level='0', core_count=3, max_turbo_frequency_mhz=3800), TurboRatioLevel(level='0', core_count=4, max_turbo_frequency_mhz=3800), TurboRatioLevel(level='0', core_count=5, max_turbo_frequency_mhz=3800), TurboRatioLevel(level='0', core_count=6, max_turbo_frequency_mhz=3800), TurboRatioLevel(level='0', core_count=7, max_turbo_frequency_mhz=3800), TurboRatioLevel(level='0', core_count=8, max_turbo_frequency_mhz=3800), TurboRatioLevel(level='0', core_count=9, max_turbo_frequency_mhz=3800), TurboRatioLevel(level='0', core_count=10, max_turbo_frequency_mhz=3800), TurboRatioLevel(level='0', core_count=11, max_turbo_frequency_mhz=3800), TurboRatioLevel(level='0', core_count=12, max_turbo_frequency_mhz=3800), TurboRatioLevel(level='0', core_count=13, max_turbo_frequency_mhz=3800), TurboRatioLevel(level='0', core_count=14, max_turbo_frequency_mhz=3800), TurboRatioLevel(level='0', core_count=15, max_turbo_frequency_mhz=3800), TurboRatioLevel(level='0', core_count=16, max_turbo_frequency_mhz=3800), TurboRatioLevel(level='0', core_count=17, max_turbo_frequency_mhz=3800), TurboRatioLevel(level='0', core_count=18, max_turbo_frequency_mhz=3800), TurboRatioLevel(level='0', core_count=19, max_turbo_frequency_mhz=3800), TurboRatioLevel(level='0', core_count=20, max_turbo_frequency_mhz=3800), TurboRatioLevel(level='0', core_count=21, max_turbo_frequency_mhz=3800), TurboRatioLevel(level='0', core_count=22, max_turbo_frequency_mhz=3800), TurboRatioLevel(level='0', core_count=23, max_turbo_frequency_mhz=3800), TurboRatioLevel(level='0', core_count=24, max_turbo_frequency_mhz=3800), TurboRatioLevel(level='0', core_count=25, max_turbo_frequency_mhz=3800), TurboRatioLevel(level='0', core_count=26, max_turbo_frequency_mhz=3800), TurboRatioLevel(level='0', core_count=27, max_turbo_frequency_mhz=3800), TurboRatioLevel(level='0', core_count=28, max_turbo_frequency_mhz=3800), TurboRatioLevel(level='0', core_count=29, max_turbo_frequency_mhz=3600), TurboRatioLevel(level='0', core_count=30, max_turbo_frequency_mhz=3600), TurboRatioLevel(level='0', core_count=31, max_turbo_frequency_mhz=3600), TurboRatioLevel(level='0', core_count=32, max_turbo_frequency_mhz=3600), TurboRatioLevel(level='0', core_count=33, max_turbo_frequency_mhz=3600), TurboRatioLevel(level='0', core_count=34, max_turbo_frequency_mhz=3600), TurboRatioLevel(level='0', core_count=35, max_turbo_frequency_mhz=3400), TurboRatioLevel(level='0', core_count=36, max_turbo_frequency_mhz=3400), TurboRatioLevel(level='0', core_count=37, max_turbo_frequency_mhz=3400), TurboRatioLevel(level='0', core_count=38, max_turbo_frequency_mhz=3400), TurboRatioLevel(level='0', core_count=39, max_turbo_frequency_mhz=3400), TurboRatioLevel(level='0', core_count=40, max_turbo_frequency_mhz=3400), TurboRatioLevel(level='0', core_count=41, max_turbo_frequency_mhz=3200), TurboRatioLevel(level='0', core_count=42, max_turbo_frequency_mhz=3200), TurboRatioLevel(level='0', core_count=43, max_turbo_frequency_mhz=3200), TurboRatioLevel(level='0', core_count=44, max_turbo_frequency_mhz=3200), TurboRatioLevel(level='0', core_count=45, max_turbo_frequency_mhz=3100), TurboRatioLevel(level='0', core_count=46, max_turbo_frequency_mhz=3100), TurboRatioLevel(level='0', core_count=47, max_turbo_frequency_mhz=3100), TurboRatioLevel(level='0', core_count=48, max_turbo_frequency_mhz=3100), TurboRatioLevel(level='0', core_count=49, max_turbo_frequency_mhz=3100), TurboRatioLevel(level='0', core_count=50, max_turbo_frequency_mhz=3100), TurboRatioLevel(level='0', core_count=51, max_turbo_frequency_mhz=3000), TurboRatioLevel(level='0', core_count=52, max_turbo_frequency_mhz=3000), TurboRatioLevel(level='0', core_count=53, max_turbo_frequency_mhz=3000), TurboRatioLevel(level='0', core_count=54, max_turbo_frequency_mhz=3000), TurboRati ...
#  Profile(package=1, die=0, cpu=56, level=0, turbo_levels=[TurboRatioLevel(level='0', core_count=1, max_turbo_frequency_mhz=3800), TurboRatioLevel(level='0', core_count=2, max_turbo_frequency_mhz=3800), TurboRatioLevel(level='0', core_count=3, max_turbo_frequency_mhz=3800), TurboRatioLevel(level='0', core_count=4, max_turbo_frequency_mhz=3800), TurboRatioLevel(level='0', core_count=5, max_turbo_frequency_mhz=3800), TurboRatioLevel(level='0', core_count=6, max_turbo_frequency_mhz=3800), TurboRatioLevel(level='0', core_count=7, max_turbo_frequency_mhz=3800), TurboRatioLevel(level='0', core_count=8, max_turbo_frequency_mhz=3800), TurboRatioLevel(level='0', core_count=9, max_turbo_frequency_mhz=3800), TurboRatioLevel(level='0', core_count=10, max_turbo_frequency_mhz=3800), TurboRatioLevel(level='0', core_count=11, max_turbo_frequency_mhz=3800), TurboRatioLevel(level='0', core_count=12, max_turbo_frequency_mhz=3800), TurboRatioLevel(level='0', core_count=13, max_turbo_frequency_mhz=3800), TurboRatioLevel(level='0', core_count=14, max_turbo_frequency_mhz=3800), TurboRatioLevel(level='0', core_count=15, max_turbo_frequency_mhz=3800), TurboRatioLevel(level='0', core_count=16, max_turbo_frequency_mhz=3800), TurboRatioLevel(level='0', core_count=17, max_turbo_frequency_mhz=3800), TurboRatioLevel(level='0', core_count=18, max_turbo_frequency_mhz=3800), TurboRatioLevel(level='0', core_count=19, max_turbo_frequency_mhz=3800), TurboRatioLevel(level='0', core_count=20, max_turbo_frequency_mhz=3800), TurboRatioLevel(level='0', core_count=21, max_turbo_frequency_mhz=3800), TurboRatioLevel(level='0', core_count=22, max_turbo_frequency_mhz=3800), TurboRatioLevel(level='0', core_count=23, max_turbo_frequency_mhz=3800), TurboRatioLevel(level='0', core_count=24, max_turbo_frequency_mhz=3800), TurboRatioLevel(level='0', core_count=25, max_turbo_frequency_mhz=3800), TurboRatioLevel(level='0', core_count=26, max_turbo_frequency_mhz=3800), TurboRatioLevel(level='0', core_count=27, max_turbo_frequency_mhz=3800), TurboRatioLevel(level='0', core_count=28, max_turbo_frequency_mhz=3800), TurboRatioLevel(level='0', core_count=29, max_turbo_frequency_mhz=3600), TurboRatioLevel(level='0', core_count=30, max_turbo_frequency_mhz=3600), TurboRatioLevel(level='0', core_count=31, max_turbo_frequency_mhz=3600), TurboRatioLevel(level='0', core_count=32, max_turbo_frequency_mhz=3600), TurboRatioLevel(level='0', core_count=33, max_turbo_frequency_mhz=3600), TurboRatioLevel(level='0', core_count=34, max_turbo_frequency_mhz=3600), TurboRatioLevel(level='0', core_count=35, max_turbo_frequency_mhz=3400), TurboRatioLevel(level='0', core_count=36, max_turbo_frequency_mhz=3400), TurboRatioLevel(level='0', core_count=37, max_turbo_frequency_mhz=3400), TurboRatioLevel(level='0', core_count=38, max_turbo_frequency_mhz=3400), TurboRatioLevel(level='0', core_count=39, max_turbo_frequency_mhz=3400), TurboRatioLevel(level='0', core_count=40, max_turbo_frequency_mhz=3400), TurboRatioLevel(level='0', core_count=41, max_turbo_frequency_mhz=3200), TurboRatioLevel(level='0', core_count=42, max_turbo_frequency_mhz=3200), TurboRatioLevel(level='0', core_count=43, max_turbo_frequency_mhz=3200), TurboRatioLevel(level='0', core_count=44, max_turbo_frequency_mhz=3200), TurboRatioLevel(level='0', core_count=45, max_turbo_frequency_mhz=3100), TurboRatioLevel(level='0', core_count=46, max_turbo_frequency_mhz=3100), TurboRatioLevel(level='0', core_count=47, max_turbo_frequency_mhz=3100), TurboRatioLevel(level='0', core_count=48, max_turbo_frequency_mhz=3100), TurboRatioLevel(level='0', core_count=49, max_turbo_frequency_mhz=3100), TurboRatioLevel(level='0', core_count=50, max_turbo_frequency_mhz=3100), TurboRatioLevel(level='0', core_count=51, max_turbo_frequency_mhz=3000), TurboRatioLevel(level='0', core_count=52, max_turbo_frequency_mhz=3000), TurboRatioLevel(level='0', core_count=53, max_turbo_frequency_mhz=3000), TurboRatioLevel(level='0', core_count=54, max_turbo_frequency_mhz=3000), TurboRati ...

# %%
print(result.profiles[0].turbo_levels)
# Out:
# [TurboRatioLevel(level='0', core_count=1, max_turbo_frequency_mhz=3800), TurboRatioLevel(level='0', core_count=2, max_turbo_frequency_mhz=3800), TurboRatioLevel(level='0', core_count=3, max_turbo_frequency_mhz=3800), TurboRatioLevel(level='0', core_count=4, max_turbo_frequency_mhz=3800), TurboRatioLevel(level='0', core_count=5, max_turbo_frequency_mhz=3800), TurboRatioLevel(level='0', core_count=6, max_turbo_frequency_mhz=3800), TurboRatioLevel(level='0', core_count=7, max_turbo_frequency_mhz=3800), TurboRatioLevel(level='0', core_count=8, max_turbo_frequency_mhz=3800), TurboRatioLevel(level='0', core_count=9, max_turbo_frequency_mhz=3800), TurboRatioLevel(level='0', core_count=10, max_turbo_frequency_mhz=3800), TurboRatioLevel(level='0', core_count=11, max_turbo_frequency_mhz=3800), TurboRatioLevel(level='0', core_count=12, max_turbo_frequency_mhz=3800), TurboRatioLevel(level='0', core_count=13, max_turbo_frequency_mhz=3800), TurboRatioLevel(level='0', core_count=14, max_turbo_frequency_mhz=3800), TurboRatioLevel(level='0', core_count=15, max_turbo_frequency_mhz=3800), TurboRatioLevel(level='0', core_count=16, max_turbo_frequency_mhz=3800), TurboRatioLevel(level='0', core_count=17, max_turbo_frequency_mhz=3800), TurboRatioLevel(level='0', core_count=18, max_turbo_frequency_mhz=3800), TurboRatioLevel(level='0', core_count=19, max_turbo_frequency_mhz=3800), TurboRatioLevel(level='0', core_count=20, max_turbo_frequency_mhz=3800), TurboRatioLevel(level='0', core_count=21, max_turbo_frequency_mhz=3800), TurboRatioLevel(level='0', core_count=22, max_turbo_frequency_mhz=3800), TurboRatioLevel(level='0', core_count=23, max_turbo_frequency_mhz=3800), TurboRatioLevel(level='0', core_count=24, max_turbo_frequency_mhz=3800), TurboRatioLevel(level='0', core_count=25, max_turbo_frequency_mhz=3800), TurboRatioLevel(level='0', core_count=26, max_turbo_frequency_mhz=3800), TurboRatioLevel(level='0', core_count=27, max_turbo_frequency_mhz=3800), TurboRatioLevel(level='0', core_count=28, max_turbo_frequency_mhz=3800), TurboRatioLevel(level='0', core_count=29, max_turbo_frequency_mhz=3600), TurboRatioLevel(level='0', core_count=30, max_turbo_frequency_mhz=3600), TurboRatioLevel(level='0', core_count=31, max_turbo_frequency_mhz=3600), TurboRatioLevel(level='0', core_count=32, max_turbo_frequency_mhz=3600), TurboRatioLevel(level='0', core_count=33, max_turbo_frequency_mhz=3600), TurboRatioLevel(level='0', core_count=34, max_turbo_frequency_mhz=3600), TurboRatioLevel(level='0', core_count=35, max_turbo_frequency_mhz=3400), TurboRatioLevel(level='0', core_count=36, max_turbo_frequency_mhz=3400), TurboRatioLevel(level='0', core_count=37, max_turbo_frequency_mhz=3400), TurboRatioLevel(level='0', core_count=38, max_turbo_frequency_mhz=3400), TurboRatioLevel(level='0', core_count=39, max_turbo_frequency_mhz=3400), TurboRatioLevel(level='0', core_count=40, max_turbo_frequency_mhz=3400), TurboRatioLevel(level='0', core_count=41, max_turbo_frequency_mhz=3200), TurboRatioLevel(level='0', core_count=42, max_turbo_frequency_mhz=3200), TurboRatioLevel(level='0', core_count=43, max_turbo_frequency_mhz=3200), TurboRatioLevel(level='0', core_count=44, max_turbo_frequency_mhz=3200), TurboRatioLevel(level='0', core_count=45, max_turbo_frequency_mhz=3100), TurboRatioLevel(level='0', core_count=46, max_turbo_frequency_mhz=3100), TurboRatioLevel(level='0', core_count=47, max_turbo_frequency_mhz=3100), TurboRatioLevel(level='0', core_count=48, max_turbo_frequency_mhz=3100), TurboRatioLevel(level='0', core_count=49, max_turbo_frequency_mhz=3100), TurboRatioLevel(level='0', core_count=50, max_turbo_frequency_mhz=3100), TurboRatioLevel(level='0', core_count=51, max_turbo_frequency_mhz=3000), TurboRatioLevel(level='0', core_count=52, max_turbo_frequency_mhz=3000), TurboRatioLevel(level='0', core_count=53, max_turbo_frequency_mhz=3000), TurboRatioLevel(level='0', core_count=54, max_turbo_frequency_mhz=3000), TurboRatioLevel(level='0', core_count=55, max_turbo_frequency_mhz= ...

# %%
license_level_to_name = {
    '0': 'SSE',
    '1': 'AVX2',
    '2': 'AVX512',
    '3': 'AMX'
}

LIC_NAME = 'License name'
CORE_COUNT = 'Number of active cores'
MAX_TURBO_FREQ = 'Maximum opportunistic turbo frequency [MHz]'

freq_vs_number_of_cores = pd.DataFrame(result.profiles[0].turbo_levels)
freq_vs_number_of_cores[LIC_NAME] = freq_vs_number_of_cores['level'].apply(lambda v: license_level_to_name[v])
freq_vs_number_of_cores[CORE_COUNT] = freq_vs_number_of_cores['core_count']
freq_vs_number_of_cores[MAX_TURBO_FREQ] = freq_vs_number_of_cores['max_turbo_frequency_mhz']

freq_vs_number_of_cores
# Out:
#     level  core_count  max_turbo_frequency_mhz License name  \
# 0       0           1                     3800          SSE
# 1       0           2                     3800          SSE
# 2       0           3                     3800          SSE
# 3       0           4                     3800          SSE
# 4       0           5                     3800          SSE
# ..    ...         ...                      ...          ...
# 275     3          52                     2200          AMX
# 276     3          53                     2200          AMX
# 277     3          54                     2200          AMX
# 278     3          55                     2200          AMX
# 279     3          56                     2200          AMX
#
#      Number of active cores  Maximum opportunistic turbo frequency [MHz]
# 0                         1                                         3800
# 1                         2                                         3800
# 2                         3                                         3800
# 3                         4                                         3800
# 4                         5                                         3800
# ..                      ...                                          ...
# 275                      52                                         2200
# 276                      53                                         2200
# 277                      54                                         2200
# 278                      55                                         2200
# 279                      56                                         2200
#
# [280 rows x 6 columns]

# %%
hue_order=['AMX', 'AVX512', 'AVX2', 'SSE']

# %%
# plt.figure(figsize=(10,6))
ax = sns.scatterplot(data=freq_vs_number_of_cores, x=CORE_COUNT, y=MAX_TURBO_FREQ, hue=LIC_NAME, linewidth=1.5, marker='o', hue_order=hue_order)

# Overlay the red markers for the SSE2 license on the left
sse_marker = freq_vs_number_of_cores[freq_vs_number_of_cores[LIC_NAME] == 'SSE']
plt.plot(sse_marker[CORE_COUNT], sse_marker[MAX_TURBO_FREQ], color=sns.color_palette()[3], linestyle='None', markeredgewidth=0.0, ms=4.5, marker=matplotlib.markers.MarkerStyle("o", fillstyle="left"))

buckets = [28,34,40,44,48,50,54,56]

for i in buckets:
    plt.axvline(x=i, color='black', dashes=[2], linewidth=1)

# ax.set_ylim(0, 4000)
ax.set_xlim(0, 58)
ax.set_xticks([0] + buckets)

plt.xticks(rotation=45)
ax.tick_params(axis='x', pad=0)

plt.savefig('../../thesis/fig/avx-frequency-license-bands.pdf', bbox_inches='tight')
